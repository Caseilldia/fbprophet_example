# %%
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in c:\users\casey\anaconda3_new\envs\py33\lib\site-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\casey\anaconda3_new\envs\py33\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in c:\users\casey\anaconda3_new\envs\py33\lib\site-packages (from plotly) (1.15.0)

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    Time Date  Product          Store     Value
# 0    1012018  2667437  QLD_CW_ST0203  2926.000
# 1    2012018  2667437  QLD_CW_ST0203  2687.531
# 2    3012018  2667437  QLD_CW_ST0203  2793.000
# 3    4012018  2667437  QLD_CW_ST0203  2394.000
# 4    5012018  2667437  QLD_CW_ST0203  2660.000

# %%
df.describe()
# Out:
#           Time Date    Product        Value
# count  1.080000e+03     1080.0  1080.000000
# mean   1.567207e+07  2667437.0  4048.117478
# std    8.791548e+06        0.0  1439.945783
# min    1.012018e+06  2667437.0  2042.813500
# 25%    8.069518e+06  2667437.0  2632.498599
# 50%    1.556702e+07  2667437.0  4256.000000
# 75%    2.308452e+07  2667437.0  5288.248910
# max    3.112202e+07  2667437.0  8147.739600

# %%
print(df['Product'].unique())
print(df['Store'].unique())
# Out:
# [2667437]
# ['QLD_CW_ST0203']

# %%
df.dtypes
# Out:
# Time Date      int64
# Product        int64
# Store         object
# Value        float64
# dtype: object

# %%
df['Year'] = df['Time Date'].apply(lambda x: str(x)[-4:])
df['Month'] = df['Time Date'].apply(lambda x: str(x)[-6:-4])
df['Day'] = df['Time Date'].apply(lambda x: str(x)[:-6])
df['ds'] = pd.DatetimeIndex(df['Month']+'-'+df['Day']+'-'+df['Year'])

# %%
df.drop(['Time Date', 'Product', 'Store', 'Year', 'Month', 'Day'], axis=1, inplace=True)
df.columns = ['y', 'ds']

# %%
df.head()
# Out:
#           y         ds
# 0  2926.000 2018-01-01
# 1  2687.531 2018-01-02
# 2  2793.000 2018-01-03
# 3  2394.000 2018-01-04
# 4  2660.000 2018-01-05

# %%
model = Prophet(interval_width = 0.95, daily_seasonality = True)
fitted_model = model.fit(df)

# %%
future = model.make_future_dataframe(periods=100,freq='D')
forecast = model.predict(future)
forecast.head()
# Out:
#           ds        trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2018-01-01  3041.489276   753.943091  3968.500090  3041.489276  3041.489276
# 1 2018-01-02  3042.246698   820.078312  4077.955536  3042.246698  3042.246698
# 2 2018-01-03  3043.004119   804.858393  3890.722653  3043.004119  3043.004119
# 3 2018-01-04  3043.761541  1030.773190  4015.025255  3043.761541  3043.761541
# 4 2018-01-05  3044.518962   890.169021  4001.937401  3044.518962  3044.518962
#
#    additive_terms  additive_terms_lower  additive_terms_upper       daily  \
# 0     -641.915345           -641.915345           -641.915345  467.724032
# 1     -652.029690           -652.029690           -652.029690  467.724032
# 2     -626.188801           -626.188801           -626.188801  467.724032
# 3     -579.252371           -579.252371           -579.252371  467.724032
# 4     -615.260367           -615.260367           -615.260367  467.724032
#
#    ...     weekly  weekly_lower  weekly_upper       yearly  yearly_lower  \
# 0  ...  16.611941     16.611941     16.611941 -1126.251318  -1126.251318
# 1  ... -11.285067    -11.285067    -11.285067 -1108.468655  -1108.468655
# 2  ...  -4.407267     -4.407267     -4.407267 -1089.505566  -1089.505566
# 3  ...  22.462032     22.462032     22.462032 -1069.438435  -1069.438435
# 4  ... -34.588120    -34.588120    -34.588120 -1048.396280  -1048.396280
#
#    yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0  -1126.251318                   0.0                         0.0
# 1  -1108.468655                   0.0                         0.0
# 2  -1089.505566                   0.0                         0.0
# 3  -1069.438435                   0.0                         0.0
# 4  -1048.396280                   0.0                         0.0
#
#    multiplicative_terms_upper         yhat
# 0                         0.0  2399.573931
# 1                         0.0  2390.217008
# 2                         0.0  2416.815318
# 3                         0.0  2464.509170
# 4                         0.0  2429.258595
#
# [5 rows x 22 columns]

# %%
plot1 = model.plot(forecast)

# %%
plt2 = model.plot_components(forecast)
